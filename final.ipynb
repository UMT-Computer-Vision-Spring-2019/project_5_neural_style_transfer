# %%
import matplotlib.pyplot as plt

# Here's where I ended up with this.
# The actual code is in the project description jupyter notebook

content = plt.imread('doug.jpg')
plt.imshow(content)

# %%
style = plt.imread('anime.jpg')
plt.imshow(style)

# %%
result = plt.imread('anime-doug.png')
plt.imshow(result)
